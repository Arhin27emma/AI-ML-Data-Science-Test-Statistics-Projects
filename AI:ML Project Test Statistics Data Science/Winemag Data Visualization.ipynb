# %%
import numpy as np
import pandas as pd

winemag = pd.read_csv(r'C:\Users\Dell\Documents\AI\MACHINE LEARNING\winemag-data.csv')

# %%
winemag.head(4)
# Out:
#    Unnamed: 0 country                                        description  \
# 0           0      US  This tremendous 100% varietal wine hails from ...
# 1           1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2           2      US  Mac Watson honors the memory of a wine once ma...
# 3           3      US  This spent 20 months in 30% new French oak, an...
#
#                             designation  points  price        province  \
# 0                     Martha's Vineyard      96  235.0      California
# 1  Carodorum Selección Especial Reserva      96  110.0  Northern Spain
# 2         Special Selected Late Harvest      96   90.0      California
# 3                               Reserve      96   65.0          Oregon
#
#             region_1           region_2             variety  \
# 0        Napa Valley               Napa  Cabernet Sauvignon
# 1               Toro                NaN       Tinta de Toro
# ...

# %%
winemag.tail(4)
# Out:
#         Unnamed: 0 country                                        description  \
# 150926      150926  France  Offers an intriguing nose with ginger, lime an...
# 150927      150927   Italy  This classic example comes from a cru vineyard...
# 150928      150928  France  A perfect salmon shade, with scents of peaches...
# 150929      150929   Italy  More Pinot Grigios should taste like this. A r...
#
#             designation  points  price            province           region_1  \
# 150926   Cuvée Prestige      91   27.0           Champagne          Champagne
# 150927    Terre di Dora      91   20.0      Southern Italy  Fiano di Avellino
# 150928  Grand Brut Rosé      90   52.0           Champagne          Champagne
# 150929              NaN      90   15.0  Northeastern Italy         Alto Adige
#
#        region_2          variety         winery
# 150926      NaN  Champagne Blend      H.Germain
# 150927      NaN      White Blend      Terredora
# ...

# %%
winemag.columns = ['No', 'country',	'description', 'designation', 'points', 'price', 'province', 'region_1', 'region_2', 'variety',	'winery']
winemag.head(4)
# Out:
#    No country                                        description  \
# 0   0      US  This tremendous 100% varietal wine hails from ...
# 1   1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2   2      US  Mac Watson honors the memory of a wine once ma...
# 3   3      US  This spent 20 months in 30% new French oak, an...
#
#                             designation  points  price        province  \
# 0                     Martha's Vineyard      96  235.0      California
# 1  Carodorum Selección Especial Reserva      96  110.0  Northern Spain
# 2         Special Selected Late Harvest      96   90.0      California
# 3                               Reserve      96   65.0          Oregon
#
#             region_1           region_2             variety  \
# 0        Napa Valley               Napa  Cabernet Sauvignon
# 1               Toro                NaN       Tinta de Toro
# 2     Knights Valley             Sonoma     Sauvignon Blanc
# ...

# %%
winemag.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150930 entries, 0 to 150929
# Data columns (total 11 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   No           150930 non-null  int64
#  1   country      150925 non-null  object
#  2   description  150930 non-null  object
#  3   designation  105195 non-null  object
#  4   points       150930 non-null  int64
#  5   price        137235 non-null  float64
#  6   province     150925 non-null  object
#  7   region_1     125870 non-null  object
#  8   region_2     60953 non-null   object
#  9   variety      150930 non-null  object
#  10  winery       150930 non-null  object
# dtypes: float64(1), int64(2), object(8)
# memory usage: 12.7+ MB

# %%
winemag.shape
# Out:
# (150930, 11)

# %%
winemag.price.dtype
#winemag.points.dtype
# Out:
# dtype('float64')

# %%
winemag.price =  winemag.price.floordiv(1)
winemag.head(4)
# Out:
#    No country                                        description  \
# 0   0      US  This tremendous 100% varietal wine hails from ...
# 1   1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2   2      US  Mac Watson honors the memory of a wine once ma...
# 3   3      US  This spent 20 months in 30% new French oak, an...
#
#                             designation  points  price        province  \
# 0                     Martha's Vineyard      96  235.0      California
# 1  Carodorum Selección Especial Reserva      96  110.0  Northern Spain
# 2         Special Selected Late Harvest      96   90.0      California
# 3                               Reserve      96   65.0          Oregon
#
#             region_1           region_2             variety  \
# 0        Napa Valley               Napa  Cabernet Sauvignon
# 1               Toro                NaN       Tinta de Toro
# 2     Knights Valley             Sonoma     Sauvignon Blanc
# ...

# %%
pd.set_option('display.precision', 2)
winemag.describe()
# Out:
#               No     points      price
# count  150930.00  150930.00  137235.00
# mean    75464.50      87.89      33.13
# std     43569.88       3.22      36.32
# min         0.00      80.00       4.00
# 25%     37732.25      86.00      16.00
# 50%     75464.50      88.00      24.00
# 75%    113196.75      90.00      40.00
# max    150929.00     100.00    2300.00

# %%
from scipy import stats
slr = stats.linregress(x = winemag.points , y = winemag.price)
slr.slope
# Out:
# nan

# %% [raw]
# slr.intercept

# %%
slr.slope*2019+slr.intercept
# Out:
# nan

# %%
import seaborn as sns
sns.set_style('darkgrid')
axes = sns.regplot(x = winemag.points , y = winemag.price)
#axes.set_ylim(0, 2500)
